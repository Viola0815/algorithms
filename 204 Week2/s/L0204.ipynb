# %% [markdown]
# # 204. Count Primes
# # https://leetcode.com/problems/count-primes/
# # filename: L0204.ipynb

# %%
from time import process_time

# %% [markdown]
# # L0204.py

# %%
############################################################
# L0204.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
# NOTHING CAN BE CHANGED
# 204. Count Primes
# https://leetcode.com/problems/count-primes/
############################################################
class Solution:
    def countPrimes(self, n: int) -> int:
        list = []
        work = [0]
        if False:
            L0204(n, list, work, "up_to_prime")
        if True:
            L0204(n, list, work, "sieve_of_eratosthenes")
        return len(list)


############################################################
#  L0204 class
############################################################
class L0204:
    def __init__(
        self, n: "int", prime_number_list: "list", work: "list of size 1", alg: "string"
    ):
        self._n = n
        self._prime_number_list = (
            prime_number_list  # You need to append this using _append_prime_number
        )
        self._work = work  # You need to increment using _increment_work_done()
        if alg == "up_to_prime":
            self.up_to_primes()
        elif alg == "sieve_of_eratosthenes":
            self.sieve_of_eratosthenes()
        else:
            assert False

    ############################################################
    # All work done goes through this routine.
    # Nothing can be changed
    ###########################################################
    def _increment_work_done(self):
        self._work[0] = self._work[0] + 1

    ############################################################
    # All prime numbers are appended to the list.
    # Nothing can be changed
    ###########################################################
    def _append_prime_number(self, p):
        self._prime_number_list.append(p)

    ##Required function to implement
    def up_to_primes(self) -> "None":
        ## NOTHING CAN BE CHANGED HERE
        ## you cannot call log from Python library
        self._up_to_primes()

    ##Required function to implement
    def sieve_of_eratosthenes(self) -> "None":
        ## NOTHING CAN BE CHANGED HERE
        ## YOU CANNOT CALL math.log from Python library
        self._sieve_of_eratosthenes()

    ############################################################
    # Implement your code BELOW
    # You can have any number of private variables and functions
    # YOU CANNOT CALL math.log from Python library
    ###########################################################
    
    ##up to primes method
    def _is_divisible_by_prime(self,n:"int",p:"list")->"bool":
        i=0
        while(p[i]*p[i])<=n:
            self._increment_work_done()
            if n%p[i]==0:
                return False
            i=i+1
        return True
    
    def _up_to_primes(self):
        if(self._n<3):
            return
        self._append_prime_number(2)
        k=self._n
        for i in range(3,k,2):
            p=self._is_divisible_by_prime(i,self._prime_number_list)
            if p==True:
                self._append_prime_number(i)

                
     ##sieve of eratosthenes 
    def _sieve_of_eratosthenes(self):
        if self._n==0 or self._n==1:
            return 0
        is_prime=[True]*self._n
        is_prime [0], is_prime [1] = False, False
        for i in range(2, int (self._n**0.5)+1):
            if is_prime[i]:
                for j in range (i*i, self._n,i):
                    is_prime [j]=False
                    self._increment_work_done()
        for num in range(2, self._n):
            if is_prime[num]:
                self._append_prime_number (num)
                self._increment_work_done()

# %% [markdown]
# # L0204Test.py

# %%
############################################################
# L0204Test.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
#           NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
#from L0204 import *
from time import process_time 

class L0204Test():
    def __init__(self):
        self._testBench()
    
    def _testBench(self):
        self._tests()
        print("ALL TESTS PASSED")

    def _print(self,s:'String',n:'int',ans:'int',steps:'int',num_prime:'int', d:'float'):
        print("---------------",s, " Method-----------------------")    
        assert(num_prime == ans)
        print(n, " has ", num_prime, " Prime. Took", steps, " steps to compute")
        print("Total CPU time in sec =",d)
        

    def _test1(self,n:'int',ans:'int'):
        print("-------------", n , "-------------------------")
        t1_start = process_time()
        up_to_prime_list = []
        work1 = [0]
        L0204(n,up_to_prime_list,work1,"up_to_prime")
        t1_stop = process_time() 
        d = t1_stop - t1_start; 
        self._print("uptoprime",n,ans,work1[0],len(up_to_prime_list),d)
        if (work1[0] == 0):
          print("How did you solve this problem in ", work1[0], "Steps")
          assert(False) ;
        
        t1_start = process_time()
        sieve_prime_number_list  = []
        work2 = [0]
        L0204(n,sieve_prime_number_list,work2,"sieve_of_eratosthenes")
        t1_stop = process_time() 
        d = t1_stop - t1_start; 
        self._print("sieve_of_eratosthenes",n,ans,work2[0],len(sieve_prime_number_list),d)
        if (work2[0] == 0):
          print("How did you solve this problem in ", work2[0], "Steps")
          assert(False) ;
        if (up_to_prime_list != sieve_prime_number_list):
            print("Prime numbers are different between two algorithms")
            assert(False)


    def _tests(self):
        n = [100,1000,10000,100000,1000000]
        a = [25,168,1229,9592,78498]
        j = 0
        for i in n:
            self._test1(i,a[j])
            j = j + 1


############################################################
# main 
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
    print("Testing Prime.py Starts")
    s = L0204Test()
    print("Testing Prime.py ENDS")
############################################################
# numCourses up
###########################################################
if (__name__    == '__main__'):
    main()
# Out:
# Testing Prime.py Starts
# ------------- 100 -------------------------
# --------------- uptoprime  Method-----------------------
# 100  has  25  Prime. Took 132  steps to compute
# Total CPU time in sec = 6.399999999961992e-05
# --------------- sieve_of_eratosthenes  Method-----------------------
# 100  has  25  Prime. Took 127  steps to compute
# Total CPU time in sec = 3.900000000012227e-05
# ------------- 1000 -------------------------
# --------------- uptoprime  Method-----------------------
# 1000  has  168  Prime. Took 2302  steps to compute
# Total CPU time in sec = 0.0005939999999999834
# --------------- sieve_of_eratosthenes  Method-----------------------
# 1000  has  168  Prime. Took 1577  steps to compute
# Total CPU time in sec = 0.0003429999999999822
# ------------- 10000 -------------------------
# --------------- uptoprime  Method-----------------------
# 10000  has  1229  Prime. Took 38754  steps to compute
# Total CPU time in sec = 0.012485999999999997
# --------------- sieve_of_eratosthenes  Method-----------------------
# 10000  has  1229  Prime. Took 18208  steps to compute
# Total CPU time in sec = 0.002874999999999961
# ------------- 100000 -------------------------
# --------------- uptoprime  Method-----------------------
# 100000  has  9592  Prime. Took 694437  steps to compute
# Total CPU time in sec = 0.0827049999999998
# --------------- sieve_of_eratosthenes  Method-----------------------
# 100000  has  9592  Prime. Took 202668  steps to compute
# Total CPU time in sec = 0.01145599999999991
# ------------- 1000000 -------------------------
# --------------- uptoprime  Method-----------------------
# 1000000  has  78498  Prime. Took 13427403  steps to compute
# Total CPU time in sec = 1.1131580000000003
# --------------- sieve_of_eratosthenes  Method-----------------------
# 1000000  has  78498  Prime. Took 2200544  steps to compute
# Total CPU time in sec = 0.1250119999999999
# ALL TESTS PASSED
# Testing Prime.py ENDS
